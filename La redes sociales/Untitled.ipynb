# %%
import pandas as pd

data = pd.read_csv('multiTimeline.csv')
df = data.copy()

# %%
df = data.iloc[:, 1:]

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df.to_csv('datosgoogle.csv', index=True)

# %%
datosgoogle = pd.read_csv('datosgoogle.csv')
datosgoogle
# Out:
#      Unnamed: 0                       Unnamed: 1  \
# 0        Semana  medio ambiente: (Todo el mundo)
# 1    2019-03-10                                9
# 2    2019-03-17                                9
# 3    2019-03-24                                9
# 4    2019-03-31                                9
# ..          ...                              ...
# 258  2024-02-11                                7
# 259  2024-02-18                                8
# 260  2024-02-25                                8
# 261  2024-03-03                                0
# 262  2024-03-10                                0
#
#                             Unnamed: 2                          Unnamed: 3  \
# 0    cambio climático: (Todo el mundo)  Huella de carbono: (Todo el mundo)
# 1                                    1                                  <1
# 2                                    1                                  <1
# ...

# %%
datosgoogle.columns = datosgoogle.iloc[0]

# Eliminamos la primera fila, ya que ahora son los nombres de las columnas
datosgoogle = datosgoogle.drop(0)

# %%
datosgoogle
# Out:
# 0        Semana medio ambiente: (Todo el mundo)  \
# 1    2019-03-10                               9
# 2    2019-03-17                               9
# 3    2019-03-24                               9
# 4    2019-03-31                               9
# 5    2019-04-07                               8
# ..          ...                             ...
# 258  2024-02-11                               7
# 259  2024-02-18                               8
# 260  2024-02-25                               8
# 261  2024-03-03                               0
# 262  2024-03-10                               0
#
# 0   cambio climático: (Todo el mundo) Huella de carbono: (Todo el mundo)  \
# 1                                   1                                 <1
# 2                                   1                                 <1
# 3                                   1                                 <1
# 4                                   1                                 <1
# ...

# %%
datosgoogle.to_csv('dg.csv', index=True)
