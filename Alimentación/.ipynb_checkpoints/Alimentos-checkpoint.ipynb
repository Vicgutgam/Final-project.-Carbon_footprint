# %%
import pandas as pd
data = pd.read_csv('food.csv')

# %%
dix = data.set_index('Entity')

# %% [markdown]
#  # PROCEDEMOS A REVISAR LA TABLA PREVIAMENTE

# %%
dix.head(3)
# Out:
#                Emissions per kilogram  Emissions per 1000 kilocalories  \
# Entity
# Ale                          0.488690                         0.317338
# Almond butter                0.387011                         0.067265
# Almond milk                  0.655888                         2.222230
#
#                Emissions per 100 grams of protein  \
# Entity
# Ale                                      0.878525
# Almond butter                            0.207599
# Almond milk                             13.595512
#
#                Emissions per 100 grams of fat  Land use per kilogram  \
# Entity
# Ale                                  2.424209               0.811485
# Almond butter                        0.079103               7.683045
# Almond milk                          4.057470               1.370106
#
#                Land use per 1000 kilocalories  \
# Entity
# Ale                                  0.601152
# Almond butter                        1.296870
# Almond milk                          2.675063
#
#                Land use per 100 grams of protein  \
# Entity
# Ale                                     1.577687
# Almond butter                           3.608433
# Almond milk                            12.687839
#
#                Land use per 100 grams of fat  Eutrophication per kilogram  \
# Entity
# Ale                                 3.065766                     1.633120
# Almond butter                       1.495297                    18.723075
# Almond milk                         4.600530                     4.148876
#
#                Eutrophication per 1000 kilocalories  ...  \
# Entity                                               ...
# Ale                                        1.156801  ...
# Almond butter                              3.165000  ...
# Almond milk                                9.317069  ...
#
#                Water scarcity per 100 grams of fat  \
# Entity
# Ale                                    7464.549375
# Almond butter                         77714.970299
# Almond milk                          431118.047177
#
#                Water withdrawals per kilogram  \
# Entity
# Ale                                 49.402842
# Almond butter                     6846.472597
# Almond milk                       1246.973783
#
#                Water withdrawals per 1000 kilocalories  \
# Entity
# Ale                                          37.873277
# Almond butter                              1151.953867
# Almond milk                                2766.258122
#
#                Water withdrawals per 100 grams of protein  \
# Entity
# Ale                                             98.984968
# Almond butter                                 3125.971106
# Almond milk                                  13432.324330
#
#                Water withdrawals per 100 grams of fat  Year  biodiversity_kg  \
# Entity
# Ale                                        181.803039  2022        19.944790
# Almond butter                             1324.701109  2022       252.788221
# Almond milk                               4286.672872  2022        50.401108
#
#                biodiversity_1000kcal  biodiversity_100gprotein  \
# Entity
# Ale                        15.570546                 39.861995
# Almond butter              42.626235                117.246387
# Almond milk                99.766367                477.142139
#
#                biodiversity_100gfat
# Entity
# Ale                       62.666331
# Almond butter             49.101614
# Almond milk              190.732797
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Eliminamos las filas que no necesitamos

# %%
columnas_a_eliminar = ['Eutrophication per kilogram', 'Eutrophication per 1000 kilocalories',
       'Eutrophication per 100 grams of protein','year','biodiversity_1000kcal',	'biodiversity_100gprotein',	'biodiversity_100gfat',
       'Eutrophication per 100 grams of fat']
dix = dix.drop(columnas_a_eliminar, axis=1)

dix
# Out:
#                   Emissions per kilogram  Emissions per 1000 kilocalories  \
# Entity
# Ale                             0.488690                         0.317338
# Almond butter                   0.387011                         0.067265
# Almond milk                     0.655888                         2.222230
# Almonds                         0.602368                         0.105029
# Apple juice                     0.458378                         0.955184
# ...                                  ...                              ...
# Vegetarian pizza                5.232976                         1.891635
# Walnuts                         2.416308                         0.409580
# Watermelon                      0.969403                         2.464087
# Wine                            1.722881                        14.623111
# Yoghurt                         3.111811                         3.986662
#
#                   Emissions per 100 grams of protein  \
# Entity
# Ale                                         0.878525
# Almond butter                               0.207599
# Almond milk                                13.595512
# Almonds                                     0.328335
# Apple juice                                29.152212
# ...                                              ...
# Vegetarian pizza                            3.773106
# Walnuts                                     1.725508
# Watermelon                                 16.335799
# Wine                                      249.889035
# Yoghurt                                     8.365670
#
#                   Emissions per 100 grams of fat  Land use per kilogram  \
# Entity
# Ale                                     2.424209               0.811485
# Almond butter                           0.079103               7.683045
# Almond milk                             4.057470               1.370106
# Almonds                                 0.119361               8.230927
# Apple juice                            19.754979               0.660629
# ...                                          ...                    ...
# Vegetarian pizza                        3.919468               6.520732
# Walnuts                                 0.492456              11.875852
# Watermelon                             22.110017               1.009878
# Wine                                  332.390402               4.333116
# Yoghurt                                33.620356               3.209721
#
#                   Land use per 1000 kilocalories  \
# Entity
# Ale                                     0.601152
# Almond butter                           1.296870
# Almond milk                             2.675063
# Almonds                                 1.423376
# Apple juice                             1.382839
# ...                                          ...
# Vegetarian pizza                        2.381733
# Walnuts                                 1.924057
# Watermelon                              2.616771
# Wine                                   15.575567
# Yoghurt                                 4.120987
#
#                   Land use per 100 grams of protein  \
# Entity
# Ale                                        1.577687
# Almond butter                              3.608433
# Almond milk                               12.687839
# Almonds                                    4.261040
# Apple juice                               43.232158
# ...                                             ...
# Vegetarian pizza                           4.769522
# Walnuts                                    7.828816
# Watermelon                                17.232334
# Wine                                     252.024497
# Yoghurt                                    8.586253
#
#                   Land use per 100 grams of fat  Water scarcity per kilogram  \
# Entity
# Ale                                    3.065766                  1891.148530
# Almond butter                          1.495297                402211.960769
# Almond milk                            4.600530                 99916.417295
# Almonds                                1.610136                372799.101063
# Apple juice                           26.246743                  3286.829617
# ...                                         ...                          ...
# Vegetarian pizza                       4.998371                 14237.870381
# Walnuts                                2.092320                160556.436125
# Watermelon                            22.874311                 13528.747411
# Wine                                 271.197030                  1925.669324
# Yoghurt                               34.333541                  6595.917073
#
#                   Water scarcity per 1000 kilocalories  ...  \
# Entity                                                  ...
# Ale                                        1417.812822  ...
# Almond butter                             67620.142757  ...
# Almond milk                              282550.644552  ...
# Almonds                                   64275.149549  ...
# Apple juice                                6754.678597  ...
# ...                                                ...  ...
# Vegetarian pizza                           5440.252959  ...
# Walnuts                                   26311.929415  ...
# Watermelon                                35695.620909  ...
# Wine                                      10997.467366  ...
# Yoghurt                                    8260.594268  ...
#
#                   Water scarcity per 100 grams of fat  \
# Entity
# Ale                                       7464.549375
# Almond butter                            77714.970299
# Almond milk                             431118.047177
# Almonds                                  72908.196078
# Apple juice                             199118.258133
# ...                                               ...
# Vegetarian pizza                         12249.088675
# Walnuts                                  28606.843189
# Watermelon                              304187.031234
# Wine                                    228692.372279
# Yoghurt                                  67305.924129
#
#                   Water withdrawals per kilogram  \
# Entity
# Ale                                    49.402842
# Almond butter                        6846.472597
# Almond milk                          1246.973783
# Almonds                              6413.314597
# Apple juice                           122.318340
# ...                                          ...
# Vegetarian pizza                      579.253113
# Walnuts                              3458.072291
# Watermelon                            743.313468
# Wine                                   93.535379
# Yoghurt                               311.749947
#
#                   Water withdrawals per 1000 kilocalories  \
# Entity
# Ale                                             37.873277
# Almond butter                                 1151.953867
# Almond milk                                   2766.258122
# Almonds                                       1106.064215
# Apple juice                                    245.723809
# ...                                                   ...
# Vegetarian pizza                               215.282138
# Walnuts                                        563.902845
# Watermelon                                    1971.260276
# Wine                                           688.774728
# Yoghurt                                        388.015091
#
#                   Water withdrawals per 100 grams of protein  \
# Entity
# Ale                                                98.984968
# Almond butter                                    3125.971106
# Almond milk                                     13432.324330
# Almonds                                          3258.085733
# Apple juice                                      6160.521065
# ...                                                      ...
# Vegetarian pizza                                  444.065726
# Walnuts                                          2236.256141
# Watermelon                                      12903.761529
# Wine                                            12616.807047
# Yoghurt                                           925.576056
#
#                   Water withdrawals per 100 grams of fat  Year  \
# Entity
# Ale                                           181.803039  2022
# Almond butter                                1324.701109  2022
# Almond milk                                  4286.672872  2022
# Almonds                                      1254.124113  2022
# Apple juice                                  8566.814616  2022
# ...                                                  ...   ...
# Vegetarian pizza                              466.740381  2022
# Walnuts                                       612.117210  2022
# Watermelon                                  16688.285306  2022
# Wine                                         7647.301258  2022
# Yoghurt                                      3137.980452  2022
#
#                   biodiversity_kg  biodiversity_1000kcal  \
# Entity
# Ale                     19.944790              15.570546
# Almond butter          252.788221              42.626235
# Almond milk             50.401108              99.766367
# Almonds                261.718501              45.213038
# Apple juice             11.021176              22.752032
# ...                           ...                    ...
# Vegetarian pizza       307.775623             108.180940
# Walnuts                260.975114              42.379569
# Watermelon              33.587313              87.819304
# Wine                    87.033818             372.045896
# Yoghurt                152.696023             193.280900
#
#                   biodiversity_100gprotein  biodiversity_100gfat
# Entity
# Ale                              39.861995             62.666331
# Almond butter                   117.246387             49.101614
# Almond milk                     477.142139            190.732797
# Almonds                         134.399913             51.438593
# Apple juice                     668.427016            551.574374
# ...                                    ...                   ...
# Vegetarian pizza                210.150691            214.389929
# Walnuts                         171.372416             46.089169
# Watermelon                      576.643845            757.983229
# Wine                           6062.107987           5642.790160
# Yoghurt                         402.300746           1608.093206
#
# [211 rows x 21 columns]

# %%
dix.index.unique()
# Out:
# Index(['Ale', 'Almond butter', 'Almond milk', 'Almonds', 'Apple juice',
#        'Apple pie', 'Apples', 'Apricot jam', 'Asparagus', 'Avocados',
#        ...
#        'Tuna', 'Vegan pizza', 'Vegetable lasagne',
#        'Vegetarian chilli con carne', 'Vegetarian curry', 'Vegetarian pizza',
#        'Walnuts', 'Watermelon', 'Wine', 'Yoghurt'],
#       dtype='object', name='Entity', length=211)

# %%
##Aquí busco organizar los productos de la lista para ver si puedo sacar alguna conlclusiones, diferenciando entre productos de origen animal y origen vegetal.

productos = [
    "Ale", "Almond butter", "Almond milk", "Almonds", "Apple juice", "Apple pie", "Apples", "Apricot jam",
    "Asparagus", "Avocados", "Bacon", "Bagels", "Baguette", "Banana loaf", "Bananas", "Beans", "Beef burger",
    "Beef curry", "Beef meatballs", "Beef mince", "Beef noodles", "Beef steak", "Beer", "Beetroot", "Biscuits",
    "Blue cheese", "Brazil nuts", "Bread", "Breakfast cereal", "Brie", "Broccoli", "Butter", "Cabbage", 
    "Caesar salad", "Camembert", "Carrot cake", "Carrots", "Cashew nuts", "Cauliflower", "Cereal bars", 
    "Cheddar cheese", "Cheesecake", "Cherry tomatoes", "Chia seeds", "Chicken breast", "Chicken burger",
    "Chicken curry", "Chicken noodles", "Chicken pasta", "Chicken sausages", "Chicken thighs", "Chicken wings",
    "Chickpeas", "Chilli con carne", "Chocolate biscuits", "Chocolate cake", "Chocolate cereals", 
    "Chocolate cheesecake", "Chocolate spread", "Cider", "Coconut milk", "Coconut oil", "Cod", 
    "Cod fish fingers", "Cod fishcakes", "Coffee beans", "Coffee pods", "Cookies", "Cottage cheese",
    "Cottage pie", "Courgettes", "Couscous", "Cow's milk", "Cracker biscuits", "Crisps", "Croissants",
    "Cucumber", "Dairy-free cheese", "Dairy-free ice cream", "Dark chocolate", "Doughnuts", "Egg noodles",
    "Eggs", "Falafels", "Feta cheese", "Flapjack", "Frozen chips (french fries)", "Frozen jacket potatoes",
    "Frozen mashed potato", "Frozen onion rings", "Frozen potato wedges", "Frozen roast potatoes",
    "Frozen sweet potato fries", "Fruit cake", "Fruit smoothies", "Garden peas", "Goat's cheese", "Granola",
    "Grapes", "Haddock risotto", "Halloumi cheese", "Ice cream", "Ice lollies", "Instant coffee", "Kale",
    "Kiwis", "Lamb (leg)", "Lamb Hotpot", "Lamb burgers", "Lamb casserole", "Lamb chops", "Lamb curry",
    "Lamb moussaka", "Lasagne sheets", "Lemons", "Lentils", "Lettuce", "Limes", "Macaroni cheese",
    "Mackerel", "Marmalade", "Meat pizza", "Meat-free burger", "Meat-free mince", "Meat-free nuggets",
    "Meat-free sausages", "Melon", "Milk chocolate", "Mixed salad", "Mozzarella cheese", "Muesli",
    "Muffins", "Mushrooms", "Naan", "Nut loaf", "Oat milk", "Olive oil", "Onions", "Orange juice", 
    "Oranges", "Pain au chocolat", "Pancakes", "Parmesan cheese", "Parsnips", "Pasta shells",
    "Peanut butter", "Peanuts", "Pears", "Pecan nuts", "Penne pasta", "Peppers", "Pineapple",
    "Pitta bread", "Popcorn", "Poppadoms", "Pork chops", "Pork loin", "Pork sausage rolls", 
    "Pork sausages", "Porridge (oatmeal)", "Potato croquettes", "Potatoes", "Prawn crackers", 
    "Prawns", "Protein bar", "Protein shake", "Pumpkin seeds", "Quiche", "Quinoa", "Rapeseed oil",
    "Raspberries", "Raspberry jam", "Rice", "Rice milk", "Rice noodles", "Ricotta cheese", "Salmon",
    "Salmon fishcakes", "Sausage rolls", "Shepherd's pie", "Shortbread biscuits", "Sourdough bread",
    "Soy desert", "Soy milk", "Soy yoghurt", "Spaghetti", "Spaghetti bolognese", "Spinach", 
    "Sponge cake", "Steak pie", "Strawberries", "Strawberry jam", "Sugar", "Sunflower oil",
    "Sunflower seeds", "Sweetcorn", "Tea", "Tofu", "Tomato ketchup", "Tomatoes", "Tortilla wraps",
    "Tuna", "Vegan pizza", "Vegetable lasagne", "Vegetarian chilli con carne", "Vegetarian curry",
    "Vegetarian pizza", "Walnuts", "Watermelon", "Wine", "Yoghurt"
]

# Categorías de productos
carne_derivados = []
bebidas = []
frutas_verduras = []

# Iterar sobre la lista de productos y asignar cada producto a su categoría correspondiente
for producto in productos:
    if "chicken" in producto.lower() or "beef" in producto.lower() or "lamb" in producto.lower() or "pork" in producto.lower() or "bacon" in producto.lower() or "ham" in producto.lower() or "sausage" in producto.lower() or "steak" in producto.lower() or "burger" in producto.lower() or "meat" in producto.lower():
        carne_derivados.append(producto)
    elif "beer" in producto.lower() or "wine" in producto.lower() or "cider" in producto.lower() or "juice" in producto.lower() or "coffee" in producto.lower() or "tea" in producto.lower() or "milk" in producto.lower() or "soda" in producto.lower() or "water" in producto.lower() or "smoothies" in producto.lower():
        bebidas.append(producto)
    else:
        frutas_verduras.append(producto)

# Imprimir las listas
print("Carne o derivados:")
print(carne_derivados)
print("\nBebidas:")
print(bebidas)
print("\nFrutas y verduras:")
print(frutas_verduras)
# Out:
# Carne o derivados:
# ['Bacon', 'Beef burger', 'Beef curry', 'Beef meatballs', 'Beef mince', 'Beef noodles', 'Beef steak', 'Chicken breast', 'Chicken burger', 'Chicken curry', 'Chicken noodles', 'Chicken pasta', 'Chicken sausages', 'Chicken thighs', 'Chicken wings', 'Lamb (leg)', 'Lamb Hotpot', 'Lamb burgers', 'Lamb casserole', 'Lamb chops', 'Lamb curry', 'Lamb moussaka', 'Meat pizza', 'Meat-free burger', 'Meat-free mince', 'Meat-free nuggets', 'Meat-free sausages', 'Pork chops', 'Pork loin', 'Pork sausage rolls', 'Pork sausages', 'Sausage rolls', 'Steak pie']
#
# Bebidas:
# ['Almond milk', 'Apple juice', 'Beer', 'Cider', 'Coconut milk', 'Coffee beans', 'Coffee pods', "Cow's milk", 'Fruit smoothies', 'Instant coffee', 'Milk chocolate', 'Oat milk', 'Orange juice', 'Rice milk', 'Soy milk', 'Tea', 'Watermelon', 'Wine']
#
# Frutas y verduras:
# ['Ale', 'Almond butter', 'Almonds', 'Apple pie', 'Apples', 'Apricot jam', 'Asparagus', 'Avocados', 'Bagels', 'Baguette', 'Banana loaf', 'Bananas', 'Beans', 'Beetroot', 'Biscuits', 'Blue cheese', 'Brazil nuts', 'Bread', 'Breakfast cereal', 'Brie', 'Broccoli', 'Butter', 'Cabbage', 'Caesar salad', 'Camembert', 'Carrot cake', 'Carrots', 'Cashew nuts', 'Cauliflower', 'Cereal bars', 'Cheddar cheese', 'Cheesecake', 'Cherry tomatoes', 'Chia seeds', 'Chickpeas', 'Chilli con carne', 'Chocolate biscuits', 'Chocolate cake', 'Chocolate cereals', 'Chocolate cheesecake', 'Chocolate spread', 'Coconut oil', 'Cod', 'Cod fish fingers', 'Cod fishcakes', 'Cookies', 'Cottage cheese', 'Cottage pie', 'Courgettes', 'Couscous', 'Cracker biscuits', 'Crisps', 'Croissants', 'Cucumber', 'Dairy-free cheese', 'Dairy-free ice cream', 'Dark chocolate', 'Doughnuts', 'Egg noodles', 'Eggs', 'Falafels', 'Feta cheese', 'Flapjack', 'Frozen chips (french fries)', 'Frozen jacket potatoes', 'Frozen mashed potato', 'Frozen onion rings', 'Frozen potato wedges', 'Frozen roast potatoes', 'Frozen sweet potato fries', 'Fruit cake', 'Garden peas', "Goat's cheese", 'Granola', 'Grapes', 'Haddock risotto', 'Halloumi cheese', 'Ice cream', 'Ice lollies', 'Kale', 'Kiwis', 'Lasagne sheets', 'Lemons', 'Lentils', 'Lettuce', 'Limes', 'Macaroni cheese', 'Mackerel', 'Marmalade', 'Melon', 'Mixed salad', 'Mozzarella cheese', 'Muesli', 'Muffins', 'Mushrooms', 'Naan', 'Nut loaf', 'Olive oil', 'Onions', 'Oranges', 'Pain au chocolat', 'Pancakes', 'Parmesan cheese', 'Parsnips', 'Pasta shells', 'Peanut butter', 'Peanuts', 'Pears', 'Pecan nuts', 'Penne pasta', 'Peppers', 'Pineapple', 'Pitta bread', 'Popcorn', 'Poppadoms', 'Porridge (oatmeal)', 'Potato croquettes', 'Potatoes', 'Prawn crackers', 'Prawns', 'Protein bar', 'Protein shake', 'Pumpkin seeds', 'Quiche', 'Quinoa', 'Rapeseed oil', 'Raspberries', 'Raspberry jam', 'Rice', 'Rice noodles', 'Ricotta cheese', 'Salmon', 'Salmon fishcakes', "Shepherd's pie", 'Shortbread biscuits', 'Sourdough bread', 'Soy desert', 'Soy yoghurt', 'Spaghetti', 'Spaghetti bolognese', 'Spinach', 'Sponge cake', 'Strawberries', 'Strawberry jam', 'Sugar', 'Sunflower oil', 'Sunflower seeds', 'Sweetcorn', 'Tofu', 'Tomato ketchup', 'Tomatoes', 'Tortilla wraps', 'Tuna', 'Vegan pizza', 'Vegetable lasagne', 'Vegetarian chilli con carne', 'Vegetarian curry', 'Vegetarian pizza', 'Walnuts', 'Yoghurt']

# %%
data.to_csv('food2.csv', index=True)

# %%
data2.describe().T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data2.describe().T
#       3 data2
#
# NameError: name 'data2' is not defined

# %%
data2.columns
# Out:
# Index(['Entity', 'Emissions per kilogram', 'Emissions per 1000 kilocalories',
#        'Emissions per 100 grams of protein', 'Emissions per 100 grams of fat',
#        'Land use per kilogram', 'Land use per 1000 kilocalories',
#        'Land use per 100 grams of protein', 'Land use per 100 grams of fat',
#        'Eutrophication per kilogram', 'Eutrophication per 1000 kilocalories',
#        'Eutrophication per 100 grams of protein',
#        'Eutrophication per 100 grams of fat', 'Water scarcity per kilogram',
#        'Water scarcity per 1000 kilocalories',
#        'Water scarcity per 100 grams of protein',
#        'Water scarcity per 100 grams of fat', 'Water withdrawals per kilogram',
#        'Water withdrawals per 1000 kilocalories',
#        'Water withdrawals per 100 grams of protein',
#        'Water withdrawals per 100 grams of fat', 'Year', 'biodiversity_kg',
#        'biodiversity_1000kcal', 'biodiversity_100gprotein',
#        'biodiversity_100gfat'],
#       dtype='object')

# %%
data.describe().T
# Out:
#                                             count           mean  \
# Emissions per kilogram                      211.0       6.728361
# Emissions per 1000 kilocalories             211.0      13.948094
# Emissions per 100 grams of protein          209.0      36.947258
# Emissions per 100 grams of fat              211.0     102.151581
# Land use per kilogram                       211.0      12.488052
# Land use per 1000 kilocalories              211.0      17.678919
# Land use per 100 grams of protein           209.0      45.653178
# Land use per 100 grams of fat               211.0     126.993903
# Water scarcity per kilogram                 211.0   24017.042793
# Water scarcity per 1000 kilocalories        211.0   17547.989831
# Water scarcity per 100 grams of protein     209.0   71251.873580
# Water scarcity per 100 grams of fat         211.0  126876.598423
# Water withdrawals per kilogram              211.0     773.528414
# Water withdrawals per 1000 kilocalories     211.0     493.091767
# Water withdrawals per 100 grams of protein  209.0    2749.676005
# Water withdrawals per 100 grams of fat      211.0    4988.728654
# Year                                        211.0    2022.000000
# biodiversity_kg                             211.0     347.304248
# biodiversity_1000kcal                       211.0    1542.696901
# biodiversity_100gprotein                    209.0    3734.891954
# biodiversity_100gfat                        211.0   11887.028438
#
#                                                       std          min  \
# Emissions per kilogram                          13.634058     0.207276
# Emissions per 1000 kilocalories                106.851887     0.067265
# Emissions per 100 grams of protein             296.130529     0.207599
# Emissions per 100 grams of fat                1023.270566     0.079103
# Land use per kilogram                           39.703513     0.395357
# Land use per 1000 kilocalories                 141.065983     0.427187
# Land use per 100 grams of protein              400.752791     0.686572
# Land use per 100 grams of fat                 1367.643304     1.032875
# Water scarcity per kilogram                  44781.648330     0.693874
# Water scarcity per 1000 kilocalories         38706.173512     0.638403
# Water scarcity per 100 grams of protein     162558.915615     0.582088
# Water scarcity per 100 grams of fat         255618.926644     4.812246
# Water withdrawals per kilogram                1010.200983     0.083715
# Water withdrawals per 1000 kilocalories        710.071817     0.077022
# Water withdrawals per 100 grams of protein    8843.916384     0.070228
# Water withdrawals per 100 grams of fat       14637.878906     0.580591
# Year                                             0.000000  2022.000000
# biodiversity_kg                                681.835951     1.804118
# biodiversity_1000kcal                        15243.246927     4.180161
# biodiversity_100gprotein                     41712.607090    11.948798
# biodiversity_100gfat                        146449.173786    17.178014
#
#                                                      25%           50%  \
# Emissions per kilogram                          1.011181      2.290114
# Emissions per 1000 kilocalories                 0.613017      1.511442
# Emissions per 100 grams of protein              3.045457      5.598533
# Emissions per 100 grams of fat                  3.220944      7.651273
# Land use per kilogram                           1.958477      3.735736
# Land use per 1000 kilocalories                  1.306445      2.257053
# Land use per 100 grams of protein               4.955486      7.897629
# Land use per 100 grams of fat                   4.612852     10.102668
# Water scarcity per kilogram                  6679.746567  11008.577172
# Water scarcity per 1000 kilocalories         2736.783910   7500.730316
# Water scarcity per 100 grams of protein     11198.887447  21364.778746
# Water scarcity per 100 grams of fat         10844.670787  25467.809001
# Water withdrawals per kilogram                172.920622    374.797127
# Water withdrawals per 1000 kilocalories       112.505929    259.985806
# Water withdrawals per 100 grams of protein    388.775031    927.516560
# Water withdrawals per 100 grams of fat        351.173003    940.924730
# Year                                         2022.000000   2022.000000
# biodiversity_kg                                36.920532    100.491958
# biodiversity_1000kcal                          27.067916     57.720686
# biodiversity_100gprotein                       99.153520    205.818953
# biodiversity_100gfat                           93.356252    256.833715
#
#                                                      75%           max
# Emissions per kilogram                          6.803799  1.297477e+02
# Emissions per 1000 kilocalories                 4.675700  1.510963e+03
# Emissions per 100 grams of protein             13.595512  4.257812e+03
# Emissions per 100 grams of fat                 20.279758  1.483853e+04
# Land use per kilogram                           9.666163  4.273311e+02
# Land use per 1000 kilocalories                  4.752491  2.023699e+03
# Land use per 100 grams of protein              18.132280  5.790334e+03
# Land use per 100 grams of fat                  27.366043  1.987121e+04
# Water scarcity per kilogram                 27556.379736  4.022120e+05
# Water scarcity per 1000 kilocalories        16172.251692  3.890860e+05
# Water scarcity per 100 grams of protein     53135.790419  1.471679e+06
# Water scarcity per 100 grams of fat         99680.807201  1.843315e+06
# Water withdrawals per kilogram                884.233335  6.846473e+03
# Water withdrawals per 1000 kilocalories       570.055960  6.402381e+03
# Water withdrawals per 100 grams of protein   2040.703131  1.148361e+05
# Water withdrawals per 100 grams of fat       3310.887218  1.721174e+05
# Year                                         2022.000000  2.022000e+03
# biodiversity_kg                               276.530744  5.400691e+03
# biodiversity_1000kcal                         133.948827  2.162682e+05
# biodiversity_100gprotein                      539.968078  6.013996e+05
# biodiversity_100gfat                          653.152325  2.123697e+06

# %%
data.index
# Out:
# Index(['Ale', 'Almond butter', 'Almond milk', 'Almonds', 'Apple juice',
#        'Apple pie', 'Apples', 'Apricot jam', 'Asparagus', 'Avocados',
#        ...
#        'Tuna', 'Vegan pizza', 'Vegetable lasagne',
#        'Vegetarian chilli con carne', 'Vegetarian curry', 'Vegetarian pizza',
#        'Walnuts', 'Watermelon', 'Wine', 'Yoghurt'],
#       dtype='object', name='Entity', length=211)

# %%
indice_maximo = data['Emissions per kilogram'].idxmax()

# Luego, puedes obtener la fila correspondiente usando iloc[]
data.iloc[indice_maximo]
# Out:
# Emissions per kilogram                          129.747715
# Emissions per 1000 kilocalories                  68.095954
# Emissions per 100 grams of protein               64.190391
# Emissions per 100 grams of fat                   146.10787
# Land use per kilogram                           427.331126
# Land use per 1000 kilocalories                  223.690135
# Land use per 100 grams of protein               211.381205
# Land use per 100 grams of fat                   478.803717
# Eutrophication per kilogram                     360.728795
# Eutrophication per 1000 kilocalories            195.523947
# Eutrophication per 100 grams of protein         178.963844
# Eutrophication per 100 grams of fat             429.900409
# Water scarcity per kilogram                   48932.712749
# Water scarcity per 1000 kilocalories          26479.393711
# Water scarcity per 100 grams of protein       24263.675429
# Water scarcity per 100 grams of fat           58382.973595
# Water withdrawals per kilogram                 1954.352984
# Water withdrawals per 1000 kilocalories        1066.173594
# Water withdrawals per 100 grams of protein      969.811765
# Water withdrawals per 100 grams of fat         2360.480947
# Entity                                          Beef steak
# Year                                                  2022
# biodiversity_kg                                 3312.25473
# biodiversity_1000kcal                          1745.609251
# biodiversity_100gprotein                       1639.813911
# biodiversity_100gfat                           3754.217587
# Name: 21, dtype: object
